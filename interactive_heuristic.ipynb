# %%
import job_queue

# %%
game = job_queue.Game()

# %% [markdown]
# ## No Delay

# %%
game.run_show()
# Out:
# turn:  2
# turn:  3
# turn:  4
# turn:  5
# turn:  6
# turn:  7
# turn:  8
# turn:  9
# turn:  10
# turn:  11
# turn:  12
# turn:  13
# turn:  14
# turn:  15
# turn:  16
# turn:  17
# turn:  18
# turn:  19
# turn:  20
# turn:  21
# turn:  22
# turn:  23
# turn:  24
# turn:  25
# turn:  26
# turn:  27
# turn:  28
# turn:  29
# turn:  30
# turn:  31
# turn:  32
# turn:  33
# turn:  34
# turn:  35
# turn:  36
# turn:  37
# turn:  38
# turn:  39
# turn:  40
# turn:  41
# turn:  42
# turn:  43
# turn:  44
# turn:  45
# turn:  46
# turn:  47
# turn:  48
# turn:  49
# turn:  50
# turn:  51
# turn:  52
# turn:  53
# turn:  54
# turn:  55
# turn:  56
# turn:  57
# {'completed': True,
#  'cost': 806,
#  'cost_score': 74.0,
#  'created_at': '2016-07-31T22:55:12.000Z',
#  'current_turn': 57,
#  'delay_turns': 0,
#  'id': 16659,
#  'jobs_completed': 492,
#  'short': True,
#  'time_score': 100.0,
#  'total_score': 174.0,
#  'updated_at': '2016-07-31T23:01:06.000Z'}

# %%
game = job_queue.Game()
game.run_show(delay=False)
# Out:
# turn:  2
# turn:  3
# turn:  4
# turn:  5
# turn:  6
# turn:  7
# turn:  8
# turn:  9
# turn:  10
# turn:  11
# turn:  12
# turn:  13
# turn:  14
# turn:  15
# turn:  16
# turn:  17
# turn:  18
# turn:  19
# turn:  20
# turn:  21
# turn:  22
# turn:  23
# turn:  24
# turn:  25
# turn:  26
# turn:  27
# turn:  28
# turn:  29
# turn:  30
# turn:  31
# turn:  32
# turn:  33
# turn:  34
# turn:  35
# turn:  36
# turn:  37
# turn:  38
# turn:  39
# turn:  40
# turn:  41
# turn:  42
# turn:  43
# turn:  44
# turn:  45
# turn:  46
# turn:  47
# turn:  48
# turn:  49
# turn:  50
# turn:  51
# turn:  52
# turn:  53
# turn:  54
# turn:  55
# turn:  56
# turn:  57
# {'completed': True,
#  'cost': 806,
#  'cost_score': 74.0,
#  'created_at': '2016-08-01T00:03:06.000Z',
#  'current_turn': 57,
#  'delay_turns': 0,
#  'id': 16674,
#  'jobs_completed': 492,
#  'short': True,
#  'time_score': 100.0,
#  'total_score': 174.0,
#  'updated_at': '2016-08-01T00:07:20.000Z'}

# %% [markdown]
# ## Delay rather than create machine

# %%
game = job_queue.Game()

# %%
game.run_show(delay=True)
# Out:
# turn:  2
# turn:  3
# turn:  4
# turn:  5
# turn:  6
# turn:  7
# turn:  8
# turn:  9
# turn:  10
# turn:  11
# turn:  12
# turn:  13
# turn:  14
# turn:  15
# turn:  16
# turn:  17
# turn:  18
# turn:  19
# turn:  20
# turn:  21
# turn:  22
# turn:  23
# turn:  24
# turn:  25
# turn:  26
# turn:  27
# turn:  28
# turn:  29
# turn:  30
# turn:  31
# turn:  32
# turn:  33
# turn:  34
# turn:  35
# turn:  36
# turn:  37
# turn:  38
# turn:  39
# turn:  40
# turn:  41
# turn:  42
# turn:  43
# turn:  44
# turn:  45
# turn:  46
# turn:  47
# turn:  48
# turn:  49
# turn:  50
# turn:  51
# turn:  52
# turn:  53
# turn:  54
# turn:  55
# turn:  56
# turn:  57
# {'completed': True,
#  'cost': 601,
#  'cost_score': 87.0,
#  'created_at': '2016-07-31T23:35:37.000Z',
#  'current_turn': 57,
#  'delay_turns': 1043,
#  'id': 16670,
#  'jobs_completed': 492,
#  'short': True,
#  'time_score': 100.0,
#  'total_score': 187.0,
#  'updated_at': '2016-07-31T23:38:17.000Z'}

# %%
game.jobs_delayed
# Out:
# 492

# %%
game = job_queue.Game()
game.run_show(delay=True, debug=True)
# Out:
# turn:  2
# ...
# {'delay_turns': 0, 'jobs_queued': 0, 'jobs_completed': 0, 'current_turn': 1, 'jobs': [{'turn': 1, 'game_type': 'short', 'memory_required': 12, 'machine_id': 459803, 'id': 22926, 'turns_required': 9, 'finished': False}], 'status': 'active', 'jobs_running': 0, 'machines_running': 0}
# ...
# 22926 459803 12
# ...
# turn:  3
# ...
# {'delay_turns': 0, 'jobs_queued': 0, 'jobs_completed': 0, 'current_turn': 2, 'jobs': [{'turn': 2, 'game_type': 'short', 'memory_required': 10, 'machine_id': 459804, 'id': 22927, 'turns_required': 6, 'finished': False}], 'status': 'active', 'jobs_running': 1, 'machines_running': 1}
# ...
# 22926 459803 12
# 22927 459804 10
# ...
# turn:  4
# ...

# %%
game = job_queue.Game()
game.run_show(delay=True, debug=False)
# Out:
# turn:  2
# turn:  3
# turn:  4
# turn:  5
# turn:  6
# turn:  7
# turn:  8
# turn:  9
# turn:  10
# turn:  11
# turn:  12
# turn:  13
# turn:  14
# turn:  15
# turn:  16
# turn:  17
# turn:  18
# turn:  19
# turn:  20
# turn:  21
# turn:  22
# turn:  23
# turn:  24
# turn:  25
# turn:  26
# turn:  27
# turn:  28
# turn:  29
# turn:  30
# turn:  31
# turn:  32
# turn:  33
# turn:  34
# turn:  35
# turn:  36
# turn:  37
# turn:  38
# turn:  39
# turn:  40
# turn:  41
# turn:  42
# turn:  43
# turn:  44
# turn:  45
# turn:  46
# turn:  47
# turn:  48
# turn:  49
# turn:  50
# turn:  51
# turn:  52
# turn:  53
# turn:  54
# turn:  55
# turn:  56
# turn:  57
# {'completed': True,
#  'cost': 601,
#  'cost_score': 87.0,
#  'created_at': '2016-07-31T23:58:44.000Z',
#  'current_turn': 57,
#  'delay_turns': 1043,
#  'id': 16673,
#  'jobs_completed': 492,
#  'short': True,
#  'time_score': 100.0,
#  'total_score': 187.0,
#  'updated_at': '2016-08-01T00:01:23.000Z'}
