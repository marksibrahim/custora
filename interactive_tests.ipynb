# %%
import job_queue

# %%
game = job_queue.Game()

# %%
game.run_show(debug=True)
# Out:
# {'jobs_running': 0, 'jobs_queued': 0, 'delay_turns': 0, 'current_turn': 1, 'jobs': [{'turn': 1, 'machine_id': 457517, 'finished': False, 'turns_required': 9, 'memory_required': 12, 'game_type': 'short', 'id': 22926}], 'status': 'active', 'machines_running': 0, 'jobs_completed': 0}
# ...
# 22926 457517 12
# ...
# 457517 52
# ...
# {'jobs_running': 1, 'jobs_queued': 0, 'delay_turns': 0, 'current_turn': 2, 'jobs': [{'turn': 2, 'machine_id': 457517, 'finished': False, 'turns_required': 6, 'memory_required': 10, 'game_type': 'short', 'id': 22927}], 'status': 'active', 'machines_running': 1, 'jobs_completed': 0}
# ...
# 22926 457517 12
# 22927 457517 10
# ...
# 457517 42
# ...
