# %%
import job_queue

# %%
game = job_queue.Game()

# %%
game.run_show(debug=True)
# Out:
# {'delay_turns': 0, 'jobs_completed': 0, 'jobs_running': 0, 'machines_running': 0, 'status': 'active', 'jobs': [{'id': 22926, 'turn': 1, 'turns_required': 9, 'game_type': 'short', 'memory_required': 12, 'finished': False, 'machine_id': 457521}], 'jobs_queued': 0, 'current_turn': 1}
# ...
# 22926 457521 12
# ...
# 457521 52
# ...
# {'delay_turns': 0, 'jobs_completed': 0, 'jobs_running': 1, 'machines_running': 1, 'status': 'active', 'jobs': [{'id': 22927, 'turn': 2, 'turns_required': 6, 'game_type': 'short', 'memory_required': 10, 'finished': False, 'machine_id': 457521}], 'jobs_queued': 0, 'current_turn': 2}
# ...
# 22926 457521 12
# 22927 457521 10
# ...
# 457521 42
# ...
